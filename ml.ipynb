# %%
#importing all necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
#Data Cleaning
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df["Engine Fuel Type"].mode()
# Out:
# 0    regular unleaded
# Name: Engine Fuel Type, dtype: object

# %%
df["Engine Fuel Type"].fillna("regular unleaded",inplace=True)

# %%
df["Engine HP"].mean()
# Out:
# 249.38607007176023

# %%
df["Engine HP"].median()
# Out:
# 227.0

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df["Engine HP"].fillna(df['Engine HP'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP               0
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df["Engine Cylinders"].describe
# Out:
# <bound method NDFrame.describe of 0        6.0
# 1        6.0
# 2        6.0
# 3        6.0
# 4        6.0
#         ...
# 11909    6.0
# 11910    6.0
# 11911    6.0
# 11912    6.0
# 11913    6.0
# Name: Engine Cylinders, Length: 11914, dtype: float64>

# %%
df["Engine Cylinders"].unique()
# Out:
# array([ 6.,  4.,  5.,  8., 12.,  0., nan, 10.,  3., 16.])

# %%
df["Engine Cylinders"].fillna(4.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP               0
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Number of Doors'].fillna(4.0,inplace=True)

# %%
df['Market Category'].value_counts()
# Out:
# Market Category
# Crossover                                          1110
# Flex Fuel                                           872
# Luxury                                              855
# Luxury,Performance                                  673
# Hatchback                                           641
#                                                    ...
# Crossover,Exotic,Luxury,Performance                   1
# Exotic,Luxury,High-Performance,Hybrid                 1
# Crossover,Exotic,Luxury,High-Performance              1
# Flex Fuel,Factory Tuner,Luxury,High-Performance       1
# Performance,Hybrid                                    1
# Name: count, Length: 71, dtype: int64

# %%
df.drop(['Market Category'],axis = 1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11914 non-null  object
#  4   Engine HP          11914 non-null  float64
#  5   Engine Cylinders   11914 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11914 non-null  float64
#  9   Vehicle Size       11914 non-null  object
#  10  Vehicle Style      11914 non-null  object
#  11  highway MPG        11914 non-null  int64
#  12  city mpg           11914 non-null  int64
#  13  Popularity         11914 non-null  int64
#  14  MSRP               11914 non-null  int64
# dtypes: float64(3), int64(5), object(7)
# ...

# %%
df["Year"]=df["Year"].astype(int)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df["Make_Encode"]=lb.fit_transform(df["Make"])

# %%
df["Model_Encode"]=lb.fit_transform(df["Model"])

# %%
df["EFT_Encode"]=lb.fit_transform(df["Engine Fuel Type"])

# %%
df["TransmissionType_Encode"]=lb.fit_transform(df["Transmission Type"])

# %%
df["Driven_Wheels_Encode"]=lb.fit_transform(df["Driven_Wheels"])

# %%
df["Vehicle Size_Encode"]=lb.fit_transform(df["Vehicle Size"])

# %%
df["Vehicle Style_Encode"]=lb.fit_transform(df["Vehicle Style"])

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.dtypes
# Out:
# Make                        object
# Model                       object
# Year                         int32
# Engine Fuel Type            object
# Engine HP                  float64
# Engine Cylinders           float64
# Transmission Type           object
# Driven_Wheels               object
# Number of Doors            float64
# Vehicle Size                object
# Vehicle Style               object
# highway MPG                  int64
# city mpg                     int64
# Popularity                   int64
# MSRP                         int64
# Make_Encode                  int32
# Model_Encode                 int32
# EFT_Encode                   int32
# TransmissionType_Encode      int32
# Driven_Wheels_Encode         int32
# Vehicle Size_Encode          int32
# Vehicle Style_Encode         int32
# dtype: object

# %%
dff=df[["Year","Engine HP","Engine Cylinders","Number of Doors","highway MPG","city mpg","Popularity","MSRP","Make_Encode","Model_Encode","EFT_Encode","TransmissionType_Encode","Driven_Wheels_Encode","Vehicle Size_Encode","Vehicle Style_Encode"]]
dff.corr()
# Out:
#                              Year  Engine HP  Engine Cylinders  \
# Year                     1.000000   0.350573         -0.041336
# Engine HP                0.350573   1.000000          0.767602
# Engine Cylinders        -0.041336   0.767602          1.000000
# Number of Doors          0.263946  -0.102934         -0.141054
# highway MPG              0.258240  -0.359457         -0.607422
# city mpg                 0.198171  -0.353894         -0.574382
# Popularity               0.073049   0.036823          0.042431
# MSRP                     0.227590   0.661402          0.531171
# Make_Encode             -0.013936  -0.226445         -0.265040
# Model_Encode             0.030913   0.001831          0.066346
# EFT_Encode              -0.253914  -0.194818         -0.073143
# TransmissionType_Encode -0.361553  -0.238357         -0.166611
# Driven_Wheels_Encode    -0.183914  -0.035007          0.084847
# Vehicle Size_Encode      0.102098   0.207912          0.197754
# ...

# %%
#Creating ML Models

X = df[["Year","Engine HP","Engine Cylinders","Number of Doors","highway MPG","city mpg","Popularity","Make_Encode","Model_Encode","EFT_Encode","TransmissionType_Encode","Driven_Wheels_Encode","Vehicle Size_Encode","Vehicle Style_Encode"]]
y = df['MSRP']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=49)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
lr = LinearRegression()
rf = RandomForestRegressor()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
lr.score(X_test,y_test)
# Out:
# 0.5806305470448974

# %%
rf.score(X_test,y_test)
# Out:
# 0.9719438734700077

# %%
rf.score(X_train,y_train)
# Out:
# 0.983385997591034

# %%
np.array(X_test.iloc[0])
# Out:
# array([2.015e+03, 5.700e+02, 8.000e+00, 4.000e+00, 2.400e+01, 1.500e+01,
#        1.715e+03, 3.700e+01, 5.890e+02, 8.000e+00, 0.000e+00, 0.000e+00,
#        1.000e+00, 1.400e+01])

# %%
np.array(X_train.iloc[0])
# Out:
# array([2.009e+03, 2.600e+02, 4.000e+00, 2.000e+00, 2.800e+01, 1.900e+01,
#        2.100e+02, 3.600e+01, 7.610e+02, 7.000e+00, 3.000e+00, 3.000e+00,
#        0.000e+00, 6.000e+00])

# %%
rf.predict([[2.015e+03, 5.700e+02, 8.000e+00, 4.000e+00, 2.400e+01, 1.500e+01,
       1.715e+03, 3.700e+01, 5.890e+02, 8.000e+00, 0.000e+00, 0.000e+00,
       1.000e+00, 1.400e+01]])
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([193754.96666667])

# %%
import pickle

# %%
# Save the model to a file using pickle
with open('model.pkl', 'wb') as model_file:
    pickle.dump(rf, model_file)
